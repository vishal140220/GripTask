# %% [markdown]
# # Importing header files necessary for analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %% [markdown]
# # Reading the dataset and checking if read properly

# %%
data=pd.read_csv("http://bit.ly/w-data")
data.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %% [markdown]
# # Splitting train and test data

# %%
X=data.iloc[:,:-1]
y=data.iloc[:,-1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state =100)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (20, 1) (5, 1) (20,) (5,)

# %% [markdown]
# # Training the model

# %%
from sklearn.linear_model import LinearRegression
regr = LinearRegression()
regr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Predicting values for test data

# %%
y_pred = regr.predict(X_test)

# %% [markdown]
# # Data visualization

# %%
plt.scatter(X_test, y_test,  color='black');
plt.plot(X_test, y_pred, color='blue', linewidth=2);
plt.xlabel("Hours");
plt.ylabel("Scores");

# %%
diff=pd.DataFrame({'Actual':y_test, 'Predicted':y_pred})
diff.reset_index(drop='True')
# Out:
#    Actual  Predicted
# 0      25  28.545123
# 1      35  39.364112
# 2      42  34.446390
# 3      62  60.018545
# 4      20  16.742590

# %% [markdown]
# # Mean absolute error

# %%
from sklearn import metrics
print ('Mean absolute error=',metrics.mean_absolute_error(y_pred,y_test))
# Out:
# Mean absolute error= 4.140342096254413

# %% [markdown]
# # Finding the score of the student if he studies 9.25 hours

# %%
hours=float(input("Enter the time studied by student in Hours"))
# Out:
# Enter the time studied by student in Hours9.25

# %%
y=regr.predict([[hours]]);
print('Student score will be',y)
# Out:
# Student score will be [92.96728365]
